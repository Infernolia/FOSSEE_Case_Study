# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/My Drive/Tree/final_trees.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0        id  ... dist_MPCB_NS  dist_MPCB_SWGT
# 0           0  14038741  ...     7.509323        4.888684
# 1           1  14038742  ...     5.708145        7.095322
# 2           2  14038743  ...     3.753423        6.400050
# 3           3  14038744  ...     5.708749        7.097067
# 4           4  14038745  ...     5.709113        7.097648
#
# [5 rows x 30 columns]

# %%
df = df.drop(columns = ['Unnamed: 0','id','sr_no'])

# %%
df.head()
# Out:
#                                            geom  ...  dist_MPCB_SWGT
# 0   POINT (73.89543905900004 18.48682755200003)  ...        4.888684
# 1  POINT (73.81630115200007 18.557149113000033)  ...        7.095322
# 2  POINT (73.79202280200006 18.505883990000022)  ...        6.400050
# 3  POINT (73.81626896600004 18.557148160000054)  ...        7.097067
# 4   POINT (73.81626192500005 18.55715006700007)  ...        7.097648
#
# [5 rows x 27 columns]

# %%
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder()

# %%
df = df.drop(columns=['remarks','other_remarks','saar_uid','special_collar'])

# %%
df.head()
# Out:
#                                            geom  ...  dist_MPCB_SWGT
# 0   POINT (73.89543905900004 18.48682755200003)  ...        4.888684
# 1  POINT (73.81630115200007 18.557149113000033)  ...        7.095322
# 2  POINT (73.79202280200006 18.505883990000022)  ...        6.400050
# 3  POINT (73.81626896600004 18.557148160000054)  ...        7.097067
# 4   POINT (73.81626192500005 18.55715006700007)  ...        7.097648
#
# [5 rows x 23 columns]

# %%
df_encoded = df

# %%
label_encoder = preprocessing.LabelEncoder() 
df_encoded['condition']= label_encoder.fit_transform(df_encoded['condition']) 
label_encoder = preprocessing.LabelEncoder() 
df_encoded['ownership']= label_encoder.fit_transform(df_encoded['ownership'])
label_encoder = preprocessing.LabelEncoder()  
df_encoded['balanced']= label_encoder.fit_transform(df_encoded['balanced'])


label_encoder = preprocessing.LabelEncoder()  
df_encoded['is_rare']= label_encoder.fit_transform(df_encoded['is_rare'])

# %%
df_encoded['flowering'].unique()
# Out:
# array(['Throughout year', 'July-January', 'January-March', 'March-May',
#        'March-September', 'July-December', 'September-November',
#        'April-October', 'April-June', 'March-August', 'March-July',
#        'March-October', 'June-September', 'January-May', 'September-June',
#        'January-April', 'December-May', 'August-May', 'October-December',
#        'January-June', 'April-May', 'October-March', 'April-August', nan,
#        'March-June', 'April-September', 'August-January',
#        'October-November', 'December-April', 'July-Febraury',
#        'Febraury-April', 'August-October', 'September-October',
#        'March-November', 'Febraury-March', 'July-August',
#        'December-March', 'February-May', 'May-June', 'March-April',
#        'November-March', 'April', 'October', 'July', 'August-March',
#        'May-August', 'December-February', 'September-March',
#        'February-July', 'January-July', 'September-January',
# ...

# %%
df_encoded['flowering'] = df_encoded['flowering'].fillna("undetermined")

# %%
df_encoded['phenology']= df_encoded['phenology'].fillna("undetermined")

# %%
label_encoder = preprocessing.LabelEncoder() 
df_encoded['flowering']= label_encoder.fit_transform(df_encoded['flowering'])
label_encoder = preprocessing.LabelEncoder() 
df_encoded['phenology']= label_encoder.fit_transform(df_encoded['phenology'])

# %%
df_encoded
# Out:
#                                                  geom  ...  dist_MPCB_SWGT
# 0         POINT (73.89543905900004 18.48682755200003)  ...        4.888684
# 1        POINT (73.81630115200007 18.557149113000033)  ...        7.095322
# 2        POINT (73.79202280200006 18.505883990000022)  ...        6.400050
# 3        POINT (73.81626896600004 18.557148160000054)  ...        7.097067
# 4         POINT (73.81626192500005 18.55715006700007)  ...        7.097648
# ...                                               ...  ...             ...
# 4009499   POINT (73.85540795000006 18.52595478100006)  ...             NaN
# 4009500    POINT (73.8550438330001 18.52438606700001)  ...             NaN
# 4009501  POINT (73.84921493600008 18.521887374000062)  ...             NaN
# 4009502  POINT (73.85049560300007 18.521745799000026)  ...             NaN
# 4009503  POINT (73.85614943100008 18.525268131000086)  ...             NaN
#
# [4009504 rows x 23 columns]

# %%
df_encoded['economic_i']= df_encoded['economic_i'].fillna("undetermined")

# %%
label_encoder = preprocessing.LabelEncoder() 
df_encoded['economic_i']= label_encoder.fit_transform(df_encoded['economic_i'])

# %%
df_encoded
# Out:
#                                                  geom  ...  dist_MPCB_SWGT
# 0         POINT (73.89543905900004 18.48682755200003)  ...        4.888684
# 1        POINT (73.81630115200007 18.557149113000033)  ...        7.095322
# 2        POINT (73.79202280200006 18.505883990000022)  ...        6.400050
# 3        POINT (73.81626896600004 18.557148160000054)  ...        7.097067
# 4         POINT (73.81626192500005 18.55715006700007)  ...        7.097648
# ...                                               ...  ...             ...
# 4009499   POINT (73.85540795000006 18.52595478100006)  ...             NaN
# 4009500    POINT (73.8550438330001 18.52438606700001)  ...             NaN
# 4009501  POINT (73.84921493600008 18.521887374000062)  ...             NaN
# 4009502  POINT (73.85049560300007 18.521745799000026)  ...             NaN
# 4009503  POINT (73.85614943100008 18.525268131000086)  ...             NaN
#
# [4009504 rows x 23 columns]

# %%
# !pip install pandas==1.0.1
# Out:
# ...
#      |████████████████████████████████| 10.1MB 3.4MB/s
# ...
# ERROR: fbprophet 0.7.1 has requirement pandas>=1.0.4, but you'll have pandas 1.0.1 which is incompatible.
# ERROR: causalnex 0.8.1 has requirement pandas<1.0,>=0.24.0, but you'll have pandas 1.0.1 which is incompatible.
# ...
#   Found existing installation: pandas 0.25.3
#     Uninstalling pandas-0.25.3:
#       Successfully uninstalled pandas-0.25.3
# ...

# %%
df_encoded.to_csv('encodedtrees.csv')

# %%
# !mv encodedtrees.csv '/content/gdrive/My Drive/Tree/'

# %%
# !pip install causalnex
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/52/3f/f6a428599e0d4497e1595030965b5ba455fd8ade6e977e3c819973c4b41d/pandas-0.25.3-cp36-cp36m-manylinux1_x86_64.whl
# ...
# ERROR: google-colab 1.0.0 has requirement pandas~=1.0.0; python_version >= "3.0", but you'll have pandas 0.25.3 which is incompatible.
# ERROR: fbprophet 0.7.1 has requirement pandas>=1.0.4, but you'll have pandas 0.25.3 which is incompatible.
# ...
#   Found existing installation: pandas 1.0.1
#     Uninstalling pandas-1.0.1:
#       Successfully uninstalled pandas-1.0.1
# ...

# %%
df = pd.read_csv('/content/gdrive/My Drive/Tree/encodedtrees.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  ... dist_MPCB_SWGT
# 0           0  ...       4.888684
# 1           1  ...       7.095322
# 2           2  ...       6.400050
# 3           3  ...       7.097067
# 4           4  ...       7.097648
#
# [5 rows x 24 columns]

# %%
df = df.drop(columns = ['geom','Unnamed: 0'])
df.head()
# Out:
#    girth_cm  height_m  canopy_dia_m  ...  dist_MPCB_KR  dist_MPCB_NS dist_MPCB_SWGT
# 0        10         2             1  ...      6.554280      7.509323       4.888684
# 1       115        10             4  ...      5.539697      5.708145       7.095322
# 2        15         2             2  ...      5.076020      3.753423       6.400050
# 3        13         2             1  ...      5.541110      5.708749       7.097067
# 4        25         7             1  ...      5.541631      5.709113       7.097648
#
# [5 rows x 22 columns]

# %%
df_encoded['road_name']= df_encoded['road_name'].fillna("undetermined")
df_encoded['botanical_name']= df_encoded['botanical_name'].fillna("undetermined")
df_encoded['common_name']= df_encoded['common_name'].fillna("undetermined")
df_encoded['local_name']= df_encoded['local_name'].fillna("undetermined")

# %%
df_encoded = df

# %%
label_encoder = preprocessing.LabelEncoder() 
df_encoded['society_name']= label_encoder.fit_transform(df_encoded['society_name']) 
label_encoder = preprocessing.LabelEncoder() 
df_encoded['road_name']= label_encoder.fit_transform(df_encoded['road_name'])
label_encoder = preprocessing.LabelEncoder()  
df_encoded['botanical_name']= label_encoder.fit_transform(df_encoded['botanical_name'])

label_encoder = preprocessing.LabelEncoder() 
df_encoded['common_name']= label_encoder.fit_transform(df_encoded['common_name']) 
label_encoder = preprocessing.LabelEncoder() 
df_encoded['local_name']= label_encoder.fit_transform(df_encoded['local_name'])

# %%
df_encoded
# Out:
#          girth_cm  height_m  ...  dist_MPCB_NS  dist_MPCB_SWGT
# 0              10         2  ...      7.509323        4.888684
# 1             115        10  ...      5.708145        7.095322
# 2              15         2  ...      3.753423        6.400050
# 3              13         2  ...      5.708749        7.097067
# 4              25         7  ...      5.709113        7.097648
# ...           ...       ...  ...           ...             ...
# 4009499        98        12  ...           NaN             NaN
# 4009500       105        12  ...           NaN             NaN
# 4009501        57        12  ...           NaN             NaN
# 4009502        11         3  ...           NaN             NaN
# 4009503        28         4  ...           NaN             NaN
#
# [4009504 rows x 22 columns]

# %%
df_encoded.to_csv('encodedtrees.csv')

# %%
# !mv encodedtrees.csv '/content/gdrive/My Drive/Tree/'
