# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("test.csv")

# %%
df
# Out:
#      Unnamed: 0                                   Filename         Text
# 0             0  TCFCD0202000010454830_M_pdf-1_account.jpg  3.48801E+13
# 1             1     TCFCD0202000010454830_M_pdf-1_ifsc.jpg  BARB0PARIVA
# 2             2     TCFCD0202000010454830_M_pdf-1_micr.jpg    390012060
# 3             3  TCFCD0202000010515086_M_pdf-1_account.jpg   5.6501E+14
# 4             4     TCFCD0202000010515086_M_pdf-1_ifsc.jpg  UTIB0000565
# ..          ...                                        ...          ...
# 923         923                                     73.jpg  85047433438
# 924         924                                     74.jpg   9.1401E+14
# 925         925                                     75.jpg   9.1701E+14
# 926         926                                      8.jpg  85047433438
# 927         927                                      9.jpg   9.1401E+14
#
# [928 rows x 3 columns]

# %%
df["loc"] = "public_test_crops/" + df["Filename"] + " " + df["Text"]

# %%
df
# Out:
#      Unnamed: 0                                   Filename         Text  \
# 0             0  TCFCD0202000010454830_M_pdf-1_account.jpg  3.48801E+13
# 1             1     TCFCD0202000010454830_M_pdf-1_ifsc.jpg  BARB0PARIVA
# 2             2     TCFCD0202000010454830_M_pdf-1_micr.jpg    390012060
# 3             3  TCFCD0202000010515086_M_pdf-1_account.jpg   5.6501E+14
# 4             4     TCFCD0202000010515086_M_pdf-1_ifsc.jpg  UTIB0000565
# ..          ...                                        ...          ...
# 923         923                                     73.jpg  85047433438
# 924         924                                     74.jpg   9.1401E+14
# 925         925                                     75.jpg   9.1701E+14
# 926         926                                      8.jpg  85047433438
# 927         927                                      9.jpg   9.1401E+14
#
#                                                    loc
# ...

# %%
df = df.drop(columns = ["Unnamed: 0", "Filename","Text"])

# %%
df
# Out:
#                                                    loc
# 0    public_test_crops/TCFCD0202000010454830_M_pdf-...
# 1    public_test_crops/TCFCD0202000010454830_M_pdf-...
# 2    public_test_crops/TCFCD0202000010454830_M_pdf-...
# 3    public_test_crops/TCFCD0202000010515086_M_pdf-...
# 4    public_test_crops/TCFCD0202000010515086_M_pdf-...
# ..                                                 ...
# 923               public_test_crops/73.jpg 85047433438
# 924                public_test_crops/74.jpg 9.1401E+14
# 925                public_test_crops/75.jpg 9.1701E+14
# 926                public_test_crops/8.jpg 85047433438
# 927                 public_test_crops/9.jpg 9.1401E+14
#
# [928 rows x 1 columns]

# %%
df.to_csv("ana.csv")
