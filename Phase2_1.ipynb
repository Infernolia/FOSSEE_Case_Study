# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
audio = pd.read_csv("/content/drive/My Drive/Awaaz/audio.csv",encoding='latin1')
episodes = pd.read_csv("/content/drive/My Drive/Awaaz/episodes.csv",encoding='latin1')
podcast = pd.read_csv("/content/drive/My Drive/Awaaz/podcast.csv",encoding='latin1')

# %%
audio
# Out:
#          event_name  episode_id  ... duration_of_view pref_language
# 0       audio_event      183044  ...                0            hi
# 1       audio_event      183098  ...                0            hi
# 2       audio_event      183044  ...                0            hi
# 3       audio_event      183044  ...                0            hi
# 4       audio_event      183062  ...                0            hi
# ...             ...         ...  ...              ...           ...
# 524874  audio_event      263398  ...               25            hi
# 524875  audio_event      263406  ...                0            hi
# 524876  audio_event      263406  ...                0            hi
# 524877  audio_event      263406  ...               10            hi
# 524878  audio_event      323433  ...                0            en
#
# [524879 rows x 19 columns]

# %%
audio = audio[['event_type','aawaz_user_id','episode_id','show_id']]

# %%
audio
# Out:
#        event_type                 aawaz_user_id  episode_id  show_id
# 0            play  2pGF8I3NKwUyNyRDxIjb6JqFFws2      183044    80693
# 1           pause  hfuITjAsdZeZZsM4N6vYD2QUEVn2      183098    80693
# 2            play  Olb1Enjo7faSYNsobcPfYzq2v7q1      183044    80693
# 3            stop  RrWWoLr8aZdMwuDhpeGMFKD2UH93      183044    80693
# 4            play  DIDUoC4T9AbbjNxWV50jeA0hKOZ2      183062    80693
# ...           ...                           ...         ...      ...
# 524874      pause  KB0DHBklv0SG3g7ufln8PP5TxXD3      263398    93289
# 524875       play  KB0DHBklv0SG3g7ufln8PP5TxXD3      263406    93289
# 524876       play  KB0DHBklv0SG3g7ufln8PP5TxXD3      263406    93289
# 524877       stop  KB0DHBklv0SG3g7ufln8PP5TxXD3      263406    93289
# 524878       play  T65akJxwh4arXwJe4zRlncPhAaV2      323433    98254
#
# [524879 rows x 4 columns]

# %%
episodes
# Out:
#       Unnamed: 0  ... time
# 0              0  ...   45
# 1              1  ...  299
# 2              2  ...  379
# 3              3  ...  312
# 4              4  ...  452
# ...          ...  ...  ...
# 5949        5949  ...  531
# 5950        5950  ...  350
# 5951        5951  ...  574
# 5952        5952  ...  605
# 5953        5953  ...  744
#
# [5954 rows x 10 columns]

# %%
podcast = podcast[['categories','sub_categories','show_id','language']]

# %%
podcast
# Out:
#      categories sub_categories  show_id language
# 0        Health           News    90129       hi
# 1        Horror        Stories    82004       hi
# 2    Devotional          Music    70515       hi
# 3    Devotional        Hanuman    87338       hi
# 4    Devotional        Tourism    92708       hi
# ..          ...            ...      ...      ...
# 136  Chinimandi     Chinimandi    94896       en
# 137  Chinimandi     Chinimandi    94952       en
# 138      Events      Talk show    97255       en
# 139  Chinimandi     Chinimandi    94920       en
# 140  Chinimandi     Chinimandi    94922       en
#
# [141 rows x 4 columns]

# %%
audio['category'] = ""
audio['subcategory'] = ""
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for i in audio.index:
  x = int(audio.at[i,'show_id'])
  for j in podcast.index:
    y = podcast.at[j,'show_id']
    if x==y:
      audio.at[i,'category'] = podcast.at[j,'categories']
      audio.at[i,'subcategory'] = podcast.at[j,'sub_categories']
      break

# %%
audio
# Out:
#        event_type                 aawaz_user_id  ...    category  subcategory
# 0            play  2pGF8I3NKwUyNyRDxIjb6JqFFws2  ...  Devotional      Godbook
# 1           pause  hfuITjAsdZeZZsM4N6vYD2QUEVn2  ...  Devotional      Godbook
# 2            play  Olb1Enjo7faSYNsobcPfYzq2v7q1  ...  Devotional      Godbook
# 3            stop  RrWWoLr8aZdMwuDhpeGMFKD2UH93  ...  Devotional      Godbook
# 4            play  DIDUoC4T9AbbjNxWV50jeA0hKOZ2  ...  Devotional      Godbook
# ...           ...                           ...  ...         ...          ...
# 524874      pause  KB0DHBklv0SG3g7ufln8PP5TxXD3  ...
# 524875       play  KB0DHBklv0SG3g7ufln8PP5TxXD3  ...
# 524876       play  KB0DHBklv0SG3g7ufln8PP5TxXD3  ...
# 524877       stop  KB0DHBklv0SG3g7ufln8PP5TxXD3  ...
# 524878       play  T65akJxwh4arXwJe4zRlncPhAaV2  ...
#
# [524879 rows x 6 columns]

# %%
audio = audio[audio['event_type']=="play"]

# %%
audio
# Out:
#        event_type                 aawaz_user_id  ...    category  subcategory
# 0            play  2pGF8I3NKwUyNyRDxIjb6JqFFws2  ...  Devotional      Godbook
# 2            play  Olb1Enjo7faSYNsobcPfYzq2v7q1  ...  Devotional      Godbook
# 4            play  DIDUoC4T9AbbjNxWV50jeA0hKOZ2  ...  Devotional      Godbook
# 5            play  nH1nJ1pFnqcxcdc2RzfQHYYWLjD3  ...  Devotional      Godbook
# 6            play  0WFtYJ213ZPLktAyNwIrFbwXK5t2  ...  Devotional      Godbook
# ...           ...                           ...  ...         ...          ...
# 524872       play  OeiWmiis1AbJXgkwbJpB854H48A2  ...
# 524873       play  KB0DHBklv0SG3g7ufln8PP5TxXD3  ...
# 524875       play  KB0DHBklv0SG3g7ufln8PP5TxXD3  ...
# 524876       play  KB0DHBklv0SG3g7ufln8PP5TxXD3  ...
# 524878       play  T65akJxwh4arXwJe4zRlncPhAaV2  ...
#
# [362326 rows x 6 columns]

# %%
l = []
for i in audio['subcategory'].unique():
  x = len(audio[audio['subcategory']==i])
  l.append(x)
  audio[i] = 0
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
audio
# Out:
#        event_type                 aawaz_user_id  ...  Tourism  Business
# 0            play  2pGF8I3NKwUyNyRDxIjb6JqFFws2  ...        0         0
# 2            play  Olb1Enjo7faSYNsobcPfYzq2v7q1  ...        0         0
# 4            play  DIDUoC4T9AbbjNxWV50jeA0hKOZ2  ...        0         0
# 5            play  nH1nJ1pFnqcxcdc2RzfQHYYWLjD3  ...        0         0
# 6            play  0WFtYJ213ZPLktAyNwIrFbwXK5t2  ...        0         0
# ...           ...                           ...  ...      ...       ...
# 524872       play  OeiWmiis1AbJXgkwbJpB854H48A2  ...        0         0
# 524873       play  KB0DHBklv0SG3g7ufln8PP5TxXD3  ...        0         0
# 524875       play  KB0DHBklv0SG3g7ufln8PP5TxXD3  ...        0         0
# 524876       play  KB0DHBklv0SG3g7ufln8PP5TxXD3  ...        0         0
# 524878       play  T65akJxwh4arXwJe4zRlncPhAaV2  ...        0         0
#
# [362326 rows x 43 columns]

# %%
audio.reset_index(inplace = True) 
audio
# Out:
#          index event_type  ... Tourism  Business
# 0            0       play  ...       0         0
# 1            2       play  ...       0         0
# 2            4       play  ...       0         0
# 3            5       play  ...       0         0
# 4            6       play  ...       0         0
# ...        ...        ...  ...     ...       ...
# 362321  524872       play  ...       0         0
# 362322  524873       play  ...       0         0
# 362323  524875       play  ...       0         0
# 362324  524876       play  ...       0         0
# 362325  524878       play  ...       0         0
#
# [362326 rows x 44 columns]

# %%
audio = audio.drop(columns=['index'])
audio
# Out:
#        event_type                 aawaz_user_id  ...  Tourism  Business
# 0            play  2pGF8I3NKwUyNyRDxIjb6JqFFws2  ...        0         0
# 1            play  Olb1Enjo7faSYNsobcPfYzq2v7q1  ...        0         0
# 2            play  DIDUoC4T9AbbjNxWV50jeA0hKOZ2  ...        0         0
# 3            play  nH1nJ1pFnqcxcdc2RzfQHYYWLjD3  ...        0         0
# 4            play  0WFtYJ213ZPLktAyNwIrFbwXK5t2  ...        0         0
# ...           ...                           ...  ...      ...       ...
# 362321       play  OeiWmiis1AbJXgkwbJpB854H48A2  ...        0         0
# 362322       play  KB0DHBklv0SG3g7ufln8PP5TxXD3  ...        0         0
# 362323       play  KB0DHBklv0SG3g7ufln8PP5TxXD3  ...        0         0
# 362324       play  KB0DHBklv0SG3g7ufln8PP5TxXD3  ...        0         0
# 362325       play  T65akJxwh4arXwJe4zRlncPhAaV2  ...        0         0
#
# [362326 rows x 43 columns]

# %%
for i in audio['subcategory'].unique():
  audio[i] = 0

# %%
for i in audio.index:
  x = audio.at[i,'subcategory']
  audio.at[i,x] = audio.at[i,x] + 1

# %%
audio
# Out:
#        event_type                 aawaz_user_id  ...  Tourism  Business
# 0            play  2pGF8I3NKwUyNyRDxIjb6JqFFws2  ...        0         0
# 1            play  Olb1Enjo7faSYNsobcPfYzq2v7q1  ...        0         0
# 2            play  DIDUoC4T9AbbjNxWV50jeA0hKOZ2  ...        0         0
# 3            play  nH1nJ1pFnqcxcdc2RzfQHYYWLjD3  ...        0         0
# 4            play  0WFtYJ213ZPLktAyNwIrFbwXK5t2  ...        0         0
# ...           ...                           ...  ...      ...       ...
# 362321       play  OeiWmiis1AbJXgkwbJpB854H48A2  ...        0         0
# 362322       play  KB0DHBklv0SG3g7ufln8PP5TxXD3  ...        0         0
# 362323       play  KB0DHBklv0SG3g7ufln8PP5TxXD3  ...        0         0
# 362324       play  KB0DHBklv0SG3g7ufln8PP5TxXD3  ...        0         0
# 362325       play  T65akJxwh4arXwJe4zRlncPhAaV2  ...        0         0
#
# [362326 rows x 43 columns]

# %%
audio = audio.drop(columns = ['event_type'])

# %%
audio.to_csv("phase2_1.csv")

# %%
# !mv phase2_1.csv '/content/drive/My Drive/Awaaz/'

# %%
audio
# Out:
#                        aawaz_user_id  episode_id  ...  Tourism Business
# 0       2pGF8I3NKwUyNyRDxIjb6JqFFws2      183044  ...        0        0
# 1       Olb1Enjo7faSYNsobcPfYzq2v7q1      183044  ...        0        0
# 2       DIDUoC4T9AbbjNxWV50jeA0hKOZ2      183062  ...        0        0
# 3       nH1nJ1pFnqcxcdc2RzfQHYYWLjD3      247660  ...        0        0
# 4       0WFtYJ213ZPLktAyNwIrFbwXK5t2      183044  ...        0        0
# ...                              ...         ...  ...      ...      ...
# 362321  OeiWmiis1AbJXgkwbJpB854H48A2      263398  ...        0        0
# 362322  KB0DHBklv0SG3g7ufln8PP5TxXD3      263398  ...        0        0
# 362323  KB0DHBklv0SG3g7ufln8PP5TxXD3      263406  ...        0        0
# 362324  KB0DHBklv0SG3g7ufln8PP5TxXD3      263406  ...        0        0
# 362325  T65akJxwh4arXwJe4zRlncPhAaV2      323433  ...        0        0
#
# [362326 rows x 42 columns]

# %%
a1 = audio[['aawaz_user_id']]
a1
# Out:
#                        aawaz_user_id
# 0       2pGF8I3NKwUyNyRDxIjb6JqFFws2
# 1       Olb1Enjo7faSYNsobcPfYzq2v7q1
# 2       DIDUoC4T9AbbjNxWV50jeA0hKOZ2
# 3       nH1nJ1pFnqcxcdc2RzfQHYYWLjD3
# 4       0WFtYJ213ZPLktAyNwIrFbwXK5t2
# ...                              ...
# 362321  OeiWmiis1AbJXgkwbJpB854H48A2
# 362322  KB0DHBklv0SG3g7ufln8PP5TxXD3
# 362323  KB0DHBklv0SG3g7ufln8PP5TxXD3
# 362324  KB0DHBklv0SG3g7ufln8PP5TxXD3
# 362325  T65akJxwh4arXwJe4zRlncPhAaV2
#
# [362326 rows x 1 columns]

# %%
a2 = pd.DataFrame.drop_duplicates(a1)
a2
# Out:
#                        aawaz_user_id
# 0       2pGF8I3NKwUyNyRDxIjb6JqFFws2
# 1       Olb1Enjo7faSYNsobcPfYzq2v7q1
# 2       DIDUoC4T9AbbjNxWV50jeA0hKOZ2
# 3       nH1nJ1pFnqcxcdc2RzfQHYYWLjD3
# 4       0WFtYJ213ZPLktAyNwIrFbwXK5t2
# ...                              ...
# 362265  BOZJNCZXlDQHq9bB0HUcBd3ovMS2
# 362275  P7m2KM51tpZkuLLAbBrwNiEtP8e2
# 362295  4tdlGeijkraOzDKWqWo3PaplUAX2
# 362299  TEsBBreFQwR2Ao0tSmhZ4pOZBaF2
# 362315  Akht1Y1ZX2eTEgw8OHjodLylfwg2
#
# [53343 rows x 1 columns]

# %%
a2.reset_index(inplace = True) 
a2.drop(columns=['index'],inplace=True)
a2
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                       aawaz_user_id
# 0      2pGF8I3NKwUyNyRDxIjb6JqFFws2
# 1      Olb1Enjo7faSYNsobcPfYzq2v7q1
# 2      DIDUoC4T9AbbjNxWV50jeA0hKOZ2
# 3      nH1nJ1pFnqcxcdc2RzfQHYYWLjD3
# 4      0WFtYJ213ZPLktAyNwIrFbwXK5t2
# ...                             ...
# 53338  BOZJNCZXlDQHq9bB0HUcBd3ovMS2
# 53339  P7m2KM51tpZkuLLAbBrwNiEtP8e2
# 53340  4tdlGeijkraOzDKWqWo3PaplUAX2
# 53341  TEsBBreFQwR2Ao0tSmhZ4pOZBaF2
# 53342  Akht1Y1ZX2eTEgw8OHjodLylfwg2
#
# [53343 rows x 1 columns]

# %%
for i in  audio['subcategory'].unique():
  a2[i] = 0
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
a2
# Out:
#                       aawaz_user_id  Godbook  ...  Tourism  Business
# 0      2pGF8I3NKwUyNyRDxIjb6JqFFws2        0  ...        0         0
# 1      Olb1Enjo7faSYNsobcPfYzq2v7q1        0  ...        0         0
# 2      DIDUoC4T9AbbjNxWV50jeA0hKOZ2        0  ...        0         0
# 3      nH1nJ1pFnqcxcdc2RzfQHYYWLjD3        0  ...        0         0
# 4      0WFtYJ213ZPLktAyNwIrFbwXK5t2        0  ...        0         0
# ...                             ...      ...  ...      ...       ...
# 53338  BOZJNCZXlDQHq9bB0HUcBd3ovMS2        0  ...        0         0
# 53339  P7m2KM51tpZkuLLAbBrwNiEtP8e2        0  ...        0         0
# 53340  4tdlGeijkraOzDKWqWo3PaplUAX2        0  ...        0         0
# 53341  TEsBBreFQwR2Ao0tSmhZ4pOZBaF2        0  ...        0         0
# 53342  Akht1Y1ZX2eTEgw8OHjodLylfwg2        0  ...        0         0
#
# [53343 rows x 38 columns]

# %%
for i in a2.index:
  mini = audio[audio['aawaz_user_id']==a2.at[i,'aawaz_user_id']]
  for j in  audio['subcategory'].unique():
    a2.at[i,j] = mini[j].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-f02a11f63fd7> in <module>()
#       1 for i in a2.index:
# ----> 2   mini = audio[audio['aawaz_user_id']==a2.at[i,'aawaz_user_id']]
#       3   for j in  audio['subcategory'].unique():
#       4     a2.at[i,j] = mini[j].sum()
#       5
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ...

# %%
a2
# Out:
#                        aawaz_user_id  episode_id  ...  Tourism Business
# 0       2pGF8I3NKwUyNyRDxIjb6JqFFws2      183044  ...        0        0
# 1       Olb1Enjo7faSYNsobcPfYzq2v7q1      183044  ...        0        0
# 2       DIDUoC4T9AbbjNxWV50jeA0hKOZ2      183062  ...        0        0
# 3       nH1nJ1pFnqcxcdc2RzfQHYYWLjD3      247660  ...        0        0
# 4       0WFtYJ213ZPLktAyNwIrFbwXK5t2      183044  ...        0        0
# ...                              ...         ...  ...      ...      ...
# 362321  OeiWmiis1AbJXgkwbJpB854H48A2      263398  ...        0        0
# 362322  KB0DHBklv0SG3g7ufln8PP5TxXD3      263398  ...        0        0
# 362323  KB0DHBklv0SG3g7ufln8PP5TxXD3      263406  ...        0        0
# 362324  KB0DHBklv0SG3g7ufln8PP5TxXD3      263406  ...        0        0
# 362325  T65akJxwh4arXwJe4zRlncPhAaV2      323433  ...        0        0
#
# [362326 rows x 42 columns]

# %%
len(audio['aawaz_user_id'].unique())
# Out:
# 53343
