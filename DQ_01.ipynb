# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
from sklearn.ensemble import RandomForestClassifier
import math
from sklearn.model_selection import train_test_split

# %%
train_dataset = pd.read_csv("energy_train.csv")
test_dataset = pd.read_csv("energy_test.csv")

train_dataset = train_dataset.set_index("id")
test_dataset = test_dataset.set_index("id")
train_dataset.dropna(axis=0,  inplace=True)

# %%
train_dataset.columns = ['Date','WattHour', 'Lumin','D1','M1','D2','M2','D3','M3','D4','M4','D5','M5','D6','M6','D7','M7','D8','M8','D9','M9','D_Cout','Pressure','M_Cout','Wind','Clarity','Dew','R1','R2']

test_dataset.columns = ['Date', 'Lumin','D1','M1','D2','M2','D3','M3','D4','M4','D5','M5','D6','M6','D7','M7','D8','M8','D9','M9','D_Cout','Pressure','M_Cout','Wind','Clarity','Dew','R1','R2']

# %%
train_dataset['X'] = train_dataset['Lumin'] + train_dataset['D1'] + train_dataset['M1'] + train_dataset['D2'] + train_dataset['M2'] +train_dataset['D3'] + train_dataset['M3'] + train_dataset['D4'] + train_dataset['M4'] + train_dataset['D5'] + train_dataset['M5'] +train_dataset['D6'] +train_dataset['M6'] +train_dataset['D7'] +train_dataset['M7'] +train_dataset['D8'] +train_dataset['M8'] +train_dataset['D9'] +train_dataset['M9'] +train_dataset['D_Cout'] + train_dataset['Pressure'] +train_dataset['M_Cout'] +train_dataset['Wind'] +train_dataset['Clarity'] +train_dataset['Dew'] +train_dataset['R1'] +train_dataset['R2']

# %%
test_dataset['X'] = test_dataset['Lumin'] + test_dataset['D1'] + test_dataset['M1'] + test_dataset['D2'] + train_dataset['M2'] +train_dataset['D3'] + train_dataset['M3'] + train_dataset['D4'] + train_dataset['M4'] + train_dataset['D5'] + train_dataset['M5'] +train_dataset['D6'] +train_dataset['M6'] +train_dataset['D7'] +train_dataset['M7'] +train_dataset['D8'] +train_dataset['M8'] +train_dataset['D9'] +train_dataset['M9'] +train_dataset['D_Cout'] + train_dataset['Pressure'] +train_dataset['M_Cout'] +train_dataset['Wind'] +train_dataset['Clarity'] +train_dataset['Dew'] +train_dataset['R1'] +train_dataset['R2']

# %%
train_dataset.dropna(axis=0,inplace=True)
train_dataset['Lumin'] = train_dataset['Lumin'].astype(float)
test_dataset['Lumin'] = test_dataset['Lumin'].astype(float)
train_dataset.round(decimals=2)
test_dataset.round(decimals=2)
np.nan_to_num(train_dataset)
np.nan_to_num(test_dataset)
train_dataset.fillna("bfill")
test_dataset.fillna("bfill")
test_dataset
# Out:
#                       Date  Lumin         D1         M1         D2         M2  \
# id
# 15001  2016-04-24 21:00:00    0.0  21.926667  35.500000  19.290000  37.500000
# 15002  2016-04-24 21:10:00    0.0  21.890000  35.400000  19.222500  37.425000
# 15003  2016-04-24 21:20:00    0.0  21.890000  35.400000  19.200000  37.466667
# 15004  2016-04-24 21:30:00    0.0  21.890000  35.400000  19.100000  37.590000
# 15005  2016-04-24 21:40:00    0.0  21.890000  35.400000  19.100000  37.590000
# ...                    ...    ...        ...        ...        ...        ...
# 19371  2016-05-25 05:20:00   10.0  23.600000  40.833333  20.856667  43.566667
# 19372  2016-05-25 05:30:00    0.0  23.666667  40.566667  20.790000  43.700000
# 19373  2016-05-25 05:40:00    0.0  23.600000  40.093333  20.700000  43.296667
# 19374  2016-05-25 05:50:00    0.0  23.600000  39.426667  20.633333  42.830000
# 19375  2016-05-25 06:00:00    0.0  23.600000  39.026667  20.600000  42.333333
#
# ...

# %%
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6493 entries, 1 to 14997
# Data columns (total 29 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      6493 non-null   object
#  1   WattHour  6493 non-null   int64
#  2   Lumin     6493 non-null   float64
#  3   D1        6493 non-null   float64
#  4   M1        6493 non-null   float64
#  5   D2        6493 non-null   float64
#  6   M2        6493 non-null   float64
#  7   D3        6493 non-null   float64
#  8   M3        6493 non-null   float64
#  9   D4        6493 non-null   float64
#  10  M4        6493 non-null   float64
#  11  D5        6493 non-null   float64
#  12  M5        6493 non-null   float64
#  13  D6        6493 non-null   float64
#  14  M6        6493 non-null   float64
#  15  D7        6493 non-null   float64
#  16  M7        6493 non-null   float64
#  17  D8        6493 non-null   float64
#  18  M8        6493 non-null   float64
# ...

# %%
test_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4375 entries, 15001 to 19375
# Data columns (total 28 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      4375 non-null   object
#  1   Lumin     4375 non-null   float64
#  2   D1        4375 non-null   float64
#  3   M1        4375 non-null   float64
#  4   D2        4375 non-null   float64
#  5   M2        4375 non-null   float64
#  6   D3        4375 non-null   float64
#  7   M3        4375 non-null   float64
#  8   D4        4375 non-null   float64
#  9   M4        4375 non-null   float64
#  10  D5        4375 non-null   float64
#  11  M5        4375 non-null   float64
#  12  D6        4375 non-null   float64
#  13  M6        4375 non-null   float64
#  14  D7        4375 non-null   float64
#  15  M7        4375 non-null   float64
#  16  D8        4375 non-null   float64
#  17  M8        4375 non-null   float64
#  18  D9        4375 non-null   float64
# ...

# %%
X = train_dataset.drop(['WattHour','Date','Lumin','R1','R2','D1','M1','D2','M2','D3','M3','D5','M5'], axis=1)
y = train_dataset["WattHour"]

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_X.fit_transform(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-7a68b31db172> in <module>
#       2 sc_X = StandardScaler()
#       3 X = sc_X.fit_transform(X)
# ----> 4 y = sc_X.fit_transform(y)
#
# ~\Anaconda3\envs\Intern1\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# ~\Anaconda3\envs\Intern1\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     667         # Reset internal state before fitting
#     668         self._reset()
# --> 669         return self.partial_fit(X, y)
#     670
#     671     def partial_fit(self, X, y=None):
#
# ...

# %%
from sklearn.model_selection import train_test_split
# here I used 20% data for test_data and 80% as train_data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

sc_y = StandardScaler()
y_train = y_train.reshape((len(y_train), 1))
y_train = sc_y.fit_transform(y_train)
y_train = y_train.ravel()

# %%
from sklearn.svm import SVR
regressor = RandomForestClassifier(n_estimators=200,criterion="entropy")

# %%
from sklearn import preprocessing
from sklearn import utils

lab_enc = preprocessing.LabelEncoder()
encoded = lab_enc.fit_transform(y_train)


regressor.fit(X_train, encoded)

# %%
encoded = lab_enc.fit_transform(y_test)
y_pred = regressor.predict(X_test)
# Printing the R^2 score
regressor.score(X_test, encoded)

# %%
from sklearn.metrics import mean_absolute_error

from sklearn.metrics import mean_squared_error
from math import sqrt

rms = sqrt(mean_squared_error(y_test, y_pred))
print("Mean squared error:", rms)

# %%
encoded = lab_enc.fit_transform(y)

regressor.fit(X, encoded)

# %%
X = np.nan_to_num(test_dataset.drop(['Date','Lumin','R1','R2','D1','M1','D2','M2','D3','M3','D5','M5'], axis=1))
y_pred = regressor.predict(X)
y_pred = y_pred.astype(int)

# %%
y = pd.DataFrame({"WattHour":y_pred})

# %%
y.head()

# %%
y.to_csv("aborules.csv",index=False)
