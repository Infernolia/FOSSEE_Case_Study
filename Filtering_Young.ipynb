# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
topics1 = pd.read_csv("topics.csv")

# %%
topics1.at[525,"tears"] = "tears"
topics1
# Out:
#             tears
# 0            nasr
# 1           young
# 2             joy
# 3    professional
# 4         forever
# ..            ...
# 521      reckless
# 522           sad
# 523          fire
# 524         party
# 525         tears
#
# [526 rows x 1 columns]

# %%
young1 = pd.read_csv("young_words.csv")
young1
# Out:
#            OMG
# 0          Lit
# 1        Salty
# 2          Sic
# 3         Sick
# 4     Snatched
# ..         ...
# 242       YMMV
# 243        YSK
# 244      Kinda
# 245  Ok boomer
# 246       GOAT
#
# [247 rows x 1 columns]

# %%
m = young1["OMG"].unique()

# %%
l = topics1["tears"].unique()

# %%
d1 = pd.read_csv('/content/drive/My Drive/Location_Clean.csv')

# %%
d1
# Out:
#         Unnamed: 0 Unnamed: 0.1  ... sentiment_polarity sentiment
# 0                0            0  ...          -0.081667  negative
# 1                1            1  ...          -0.125000  negative
# 2                2            2  ...           0.000000   neutral
# 3                3            3  ...           0.000000   neutral
# 4                4            4  ...           0.000000   neutral
# ...            ...          ...  ...                ...       ...
# 105159      105159          761  ...           0.197273  positive
# 105160      105160          762  ...          -0.111111  negative
# 105161      105161          763  ...           0.125000  positive
# 105162      105162          764  ...          -0.100000  negative
# 105163      105163          765  ...           0.275000  positive
#
# [105164 rows x 13 columns]

# %%
import nltk

from nltk.tokenize import word_tokenize 
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
l

from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
  

  
stop_words = set(stopwords.words('english')) 
  

  
filtered_sentence = [w for w in l if not w in stop_words] 
  
filtered_sentence = [] 
  
for w in l: 
    if w not in stop_words: 
        filtered_sentence.append(w) 
  
print(l) 
print(filtered_sentence)
# Out:
# ['nasr' 'young' 'joy' 'professional' 'forever' 'world' 'face' 'services'
#  'die' 'with' 'city' 'man' 'from' 'live' 'one' 'ah' 'up' 'people' 'today'
#  'eii' 'cairo' 'cafe' 'future' 'college' 'stay' 'best' 'siaa' 'youth'
#  'old' 'teen' 'cairoconfusionçµ' 'has' 'fire' 'wupy' 'ashley' 'all'
#  'tongue' 'fast' 'most' 'smh' 'thumbs' 'free' 'who' 'pleading' 'hussein'
#  'lady' 'day' 'winking' 'club' 'wanna' 'part' 'chale' 'boy' 'team' 'sweat'
#  'ammanconfusionªå' 'thug' 'first' 'bro' 'about' 'good' 'last' 'ye' 'know'
#  'night' 'will' 'awww' 'king' 'wild' 'smiling' 'you' 'we' 'twitter' 'eyes'
#  'your' 'our' 'com' 're' 'do' 'were' 'grinning' 'if' 'have' 'beaming'
#  'can' 'bei' 'hearts' 'thank' 'need' 'sunglasses' 'heart' 'll' 'youngk'
#  'while' 'don' 'reckless' 'by' 'what' 'us' 'medway' 'when' 'cat' 'like'
#  'are' 'big' 'never' 'tonight' 'rolling' 'things' 'now' 'forum' 'biceps'
#  'hand' 'but' 'new' 'flexed' 'nothing' '2020' 'halo' 'think' 'saeng'
# ...

# %%
d1["Age"] = ""
d1["Topic"] = ""

for i in d1.index:
  text = str(d1.at[i,"without_emoji"])
  words = word_tokenize(text)
  for j in words:
    if ((j in m) or (d1.at[i,"emoji_count"]>0.0)):
      d1.at[i,"Age"] = "Y"
    else:
      d1.at[i,"Age"] = "N"

    if j in filtered_sentence:
      d1.at[i,"Topic"] =  d1.at[i,"Topic"] + " " + str(j)

# %%
d1
# Out:
#         Unnamed: 0 Unnamed: 0.1  ... Age                                  Topic
# 0                0            0  ...   N                know teen see like shit
# 1                1            1  ...   Y               teen face face face face
# 2                2            2  ...   N
# 3                3            3  ...   Y                              face face
# 4                4            4  ...   Y                          la de la teen
# ...            ...          ...  ...  ..                                    ...
# 105159      105159          761  ...   N   thanks youth night live thanks heart
# 105160      105160          762  ...   N                            today youth
# 105161      105161          763  ...   N                            youth young
# 105162      105162          764  ...   N                     youth family youth
# 105163      105163          765  ...   Y               give life us care family
#
# [105164 rows x 15 columns]

# %%
d1['Age'].value_counts()
# Out:
# N    89273
# Y    15891
# Name: Age, dtype: int64

# %%
d1 = d1.drop(columns = ["Unnamed: 0", "Unnamed: 0.1"])

# %%
d1
# Out:
#                          id keyword  ... Age                                  Topic
# 0       1273695716335108097    teen  ...   N                know teen see like shit
# 1       1273695712908382208    teen  ...   Y               teen face face face face
# 2       1273695547451478022    teen  ...   N
# 3       1273695477092044800    teen  ...   Y                              face face
# 4       1273695460495163395    teen  ...   Y                          la de la teen
# ...                     ...     ...  ...  ..                                    ...
# 105159  1272704282303672320   youth  ...   N   thanks youth night live thanks heart
# 105160  1272700656835534853   youth  ...   N                            today youth
# 105161  1272698869478912001   youth  ...   N                            youth young
# 105162  1272696530441388032   youth  ...   N                     youth family youth
# 105163  1272691562246361088   youth  ...   Y               give life us care family
#
# ...

# %%
for i in d1.index:
  d1.at[i,"Topic"] =  word_tokenize(str(d1.at[i,"Topic"]))

d1
# Out:
#                          id  ...                                        Topic
# 0       1273695716335108097  ...                [know, teen, see, like, shit]
# 1       1273695712908382208  ...               [teen, face, face, face, face]
# 2       1273695547451478022  ...                                           []
# 3       1273695477092044800  ...                                 [face, face]
# 4       1273695460495163395  ...                           [la, de, la, teen]
# ...                     ...  ...                                          ...
# 105159  1272704282303672320  ...  [thanks, youth, night, live, thanks, heart]
# 105160  1272700656835534853  ...                               [today, youth]
# 105161  1272698869478912001  ...                               [youth, young]
# 105162  1272696530441388032  ...                       [youth, family, youth]
# 105163  1272691562246361088  ...               [give, life, us, care, family]
#
# [105164 rows x 13 columns]

# %%
d1 = d1[d1["Age"]=="Y"]

# %%
d1 = d1[['keyword','country','without_emoji','date','hashtags','sentiment_polarity','sentiment','Topic']]
d1
# Out:
#        keyword    country  ... sentiment                                      Topic
# 1         teen  Australia  ...  negative             [teen, face, face, face, face]
# 3         teen  Australia  ...   neutral                               [face, face]
# 4         teen  Australia  ...   neutral                         [la, de, la, teen]
# 6         teen  Australia  ...   neutral  [smiling, face, smiling, eyes, teen, day]
# 7         teen  Australia  ...  negative    [life, new, teen, loudly, crying, face]
# ...        ...        ...  ...       ...                                        ...
# 105090   youth        USA  ...  positive                              [much, youth]
# 105130   youth        USA  ...  positive        [people, youth, one, youth, thumbs]
# 105136   youth        USA  ...  positive                         [youth, 2020, big]
# 105137   youth        USA  ...   neutral                                     [last]
# ...

# %%
d1.to_csv("Location.csv")

# %%
topics1 = pd.read_csv("Topics_Event.csv")
topics1
l = topics1["helloboon"].unique()
d1 = pd.read_csv('/content/drive/My Drive/emoji_replaced/English_Event_without_emoji.csv')
filtered_sentence = [w for w in l if not w in stop_words] 
  
filtered_sentence = [] 
  
for w in l: 
    if w not in stop_words: 
        filtered_sentence.append(w) 

d1["Age"] = ""
d1["Topic"] = ""

for i in d1.index:
  text = str(d1.at[i,"without_emoji"])
  words = word_tokenize(text)
  for j in words:
    if ((j in m) or (d1.at[i,"emoji_count"]>0.0)):
      d1.at[i,"Age"] = "Y"
    else:
      d1.at[i,"Age"] = "N"

    if j in filtered_sentence:
      d1.at[i,"Topic"] =  d1.at[i,"Topic"] + " " + str(j)

d1 = d1.drop(columns = ["Unnamed: 0", "Unnamed: 0.1"])

for i in d1.index:
  d1.at[i,"Topic"] =  word_tokenize(str(d1.at[i,"Topic"]))

d1
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                   id  ...                                   Topic
# 0       1.120639e+18  ...                      [literally, https]
# 1       1.120639e+18  ...  [agntecarter, emotional, sorry, https]
# 2       1.120639e+18  ...                                 [https]
# 3       1.120639e+18  ...                [ads, everywhere, https]
# 4       1.120639e+18  ...                         [salute, https]
# ...              ...  ...                                     ...
# 364740  1.631605e+09  ...                                 [still]
# 364741  1.468509e+09  ...                                      []
# 364742  1.310505e+09  ...                                 [movie]
# 364743  9.848846e+08  ...                         [woman, family]
# ...

# %%
d1 = d1[d1["Age"]=="Y"]
d1.to_csv("Event.csv")

# %%
topics1 = pd.read_csv("Topics_Org.csv")
topics1
# Out:
#                                 of
# 0                              amp
# 1                               we
# 2                               is
# 3                              you
# 4                              one
# ..                             ...
# 575                        refugee
# 576                         affect
# 577                  unprecedented
# 578                       register
# 579  oceaninnovationchallengeabout
#
# [580 rows x 1 columns]

# %%
l = topics1["of"].unique()
d1 = pd.read_csv('/content/drive/My Drive/emoji_replaced/English_Org_without_emoji.csv')
filtered_sentence = [w for w in l if not w in stop_words] 
  
filtered_sentence = [] 
  
for w in l: 
    if w not in stop_words: 
        filtered_sentence.append(w) 

d1["Age"] = ""
d1["Topic"] = ""

for i in d1.index:
  text = str(d1.at[i,"without_emoji"])
  words = word_tokenize(text)
  for j in words:
    if ((j in m) or (d1.at[i,"emoji_count"]>0.0)):
      d1.at[i,"Age"] = "Y"
    else:
      d1.at[i,"Age"] = "N"

    if j in filtered_sentence:
      d1.at[i,"Topic"] =  d1.at[i,"Topic"] + " " + str(j)

d1 = d1.drop(columns = ["Unnamed: 0", "Unnamed: 0.1"])

for i in d1.index:
  d1.at[i,"Topic"] =  word_tokenize(str(d1.at[i,"Topic"]))

d1
# Out:
#                 id  ...                                              Topic
# 0     1.270720e+18  ...           [world, unprecedented, economic, crisis]
# 1     1.270690e+18  ...                                                 []
# 2     1.270680e+18  ...                                             [much]
# 3     1.270670e+18  ...                                  [faster, support]
# 4     1.270610e+18  ...                                   [years, poverty]
# ...            ...  ...                                                ...
# 6442  3.195000e+03  ...  [children, today, facing, new, challenges, glo...
# 6443  3.196000e+03  ...  [years, hold, children, rights, unicefchief, s...
# 6444  3.197000e+03  ...  [unicefchief, children, today, facing, challen...
# 6445  3.198000e+03  ...          [unicefchief, need, change, years, since]
# 6446  3.199000e+03  ...                                                 []
#
# [6447 rows x 8 columns]

# %%
d1 = d1[d1["Age"]=="Y"]
d1.to_csv("Org.csv")

# %%
topics1 = pd.read_csv("Topics_Keyword.csv")
topics1
# Out:
#          work
# 0       tears
# 1       bully
# 2    petition
# 3      parent
# 4       learn
# ..        ...
# 589  increase
# 590   support
# 591       two
# 592     would
# 593  everyone
#
# [594 rows x 1 columns]

# %%
l = topics1["work"].unique()
d1 = pd.read_csv('/content/drive/My Drive/emoji_replaced/English_Keyword_without_emoji.csv')
filtered_sentence = [w for w in l if not w in stop_words] 
  
filtered_sentence = [] 
  
for w in l: 
    if w not in stop_words: 
        filtered_sentence.append(w) 

d1["Age"] = ""
d1["Topic"] = ""

for i in d1.index:
  text = str(d1.at[i,"without_emoji"])
  words = word_tokenize(text)
  for j in words:
    if ((j in m) or (d1.at[i,"emoji_count"]>0.0)):
      d1.at[i,"Age"] = "Y"
    else:
      d1.at[i,"Age"] = "N"

    if j in filtered_sentence:
      d1.at[i,"Topic"] =  d1.at[i,"Topic"] + " " + str(j)

d1 = d1.drop(columns = ["Unnamed: 0", "Unnamed: 0.1"])

for i in d1.index:
  d1.at[i,"Topic"] =  word_tokenize(str(d1.at[i,"Topic"]))

d1
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (2,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                  id   keyword  ... Age                                        Topic
# 0       1.27304e+18  bullying  ...   N                                      [cyber]
# 1       1.27304e+18  bullying  ...   N                               [school, long]
# 2       1.27304e+18  bullying  ...   N                                      [stand]
# 3       1.27304e+18  bullying  ...   N                       [everyone, well, good]
# 4       1.27304e+18  bullying  ...   N                                           []
# ...             ...       ...  ...  ..                                          ...
# 650733          NaN   college  ...   N                                           []
# ...

# %%
d1.to_csv("Keyword.csv")

# %%
d1 = d1[d1["Age"]=="Y"]

# %%
d1
# Out:
#                  id  ...                                         Topic
# 143     1.27304e+18  ...                                       [thank]
# 756     1.27303e+18  ...                   [bad, suicide, bad, people]
# 1774    1.27302e+18  ...                                            []
# 2766    1.27301e+18  ...                                        [like]
# 4204    1.27303e+18  ...  [open, case, help, someone, far, depression]
# ...             ...  ...                                           ...
# 650434  1.20068e+18  ...                                       [https]
# 650536  1.20027e+18  ...                                  [motivation]
# 650570          NaN  ...                                            []
# 650582   1.2001e+18  ...                                            []
# 650700          NaN  ...                          [youth, development]
#
# [50103 rows x 11 columns]

# %%
d1.to_csv("Keyword.csv")
