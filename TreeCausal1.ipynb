# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df = pd.read_csv('/content/gdrive/My Drive/Tree/tree_dist.csv')
df.head()
# Out:
#    Unnamed: 0  girth_cm  height_m  ...  dist_MPCB_KR dist_MPCB_NS dist_MPCB_SWGT
# 0           0        10         2  ...      6.554280     7.509323       4.888684
# 1           1       115        10  ...      5.539697     5.708145       7.095322
# 2           2        15         2  ...      5.076020     3.753423       6.400050
# 3           3        13         2  ...      5.541110     5.708749       7.097067
# 4           4        25         7  ...      5.541631     5.709113       7.097648
#
# [5 rows x 11 columns]

# %%
df1 = pd.read_csv('/content/gdrive/My Drive/Tree/trees_cleaned.csv')
df1.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          id                                          geom  ...  ward  is_rare
# 0  14038741   POINT (73.89543905900004 18.48682755200003)  ...    61    False
# 1  14038742  POINT (73.81630115200007 18.557149113000033)  ...     8    False
# 2  14038743  POINT (73.79202280200006 18.505883990000022)  ...    29    False
# 3  14038744  POINT (73.81626896600004 18.557148160000054)  ...     8    False
# 4  14038745   POINT (73.81626192500005 18.55715006700007)  ...     8    False
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009504 entries, 0 to 4009503
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Unnamed: 0      int64
#  1   girth_cm        int64
#  2   height_m        int64
#  3   canopy_dia_m    int64
#  4   condition       object
#  5   common_name     object
#  6   ward            int64
#  7   is_rare         object
#  8   dist_MPCB_KR    float64
#  9   dist_MPCB_NS    float64
#  10  dist_MPCB_SWGT  float64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 336.5+ MB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009623 entries, 0 to 4009622
# Data columns (total 26 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   id              int64
#  1   geom            object
#  2   sr_no           float64
#  3   girth_cm        int64
#  4   height_m        int64
#  5   canopy_dia_m    int64
#  6   condition       object
#  7   other_remarks   float64
#  8   ownership       object
#  9   society_name    object
#  10  road_name       object
#  11  northing        float64
#  12  easting         float64
#  13  balanced        bool
#  14  remarks         object
#  15  special_collar  object
#  16  ward_name       int64
#  17  botanical_name  object
#  18  saar_uid        int64
#  19  common_name     object
#  20  local_name      object
#  21  economic_i      object
#  22  phenology       object
#  23  flowering       object
#  24  ward            int64
#  25  is_rare         object
# ...

# %%
df.tail()
# Out:
#          Unnamed: 0  girth_cm  ...  dist_MPCB_NS  dist_MPCB_SWGT
# 4009499     4009499        98  ...      3.618743        2.517162
# 4009500     4009500       105  ...      3.487730        2.339289
# 4009501     4009501        57  ...      2.823709        2.077772
# 4009502     4009502        11  ...      2.925342        2.043180
# 4009503     4009503        28  ...      3.639340        2.452014
#
# [5 rows x 11 columns]

# %%
df1.tail()
# Out:
#                id                                          geom  ...  ward  is_rare
# 4009618  18048359   POINT (73.85540795000006 18.52595478100006)  ...    24    False
# 4009619  18048360    POINT (73.8550438330001 18.52438606700001)  ...    24    False
# 4009620  18048361  POINT (73.84921493600008 18.521887374000062)  ...    24    False
# 4009621  18048362  POINT (73.85049560300007 18.521745799000026)  ...    24    False
# 4009622  18048363  POINT (73.85614943100008 18.525268131000086)  ...    24    False
#
# [5 rows x 26 columns]

# %%
l = []
j= 0
for i in df1.index:
  try:
    if df1.at[i,'height_m'] != df.at[j,'height_m']:
        l.append(df1.at[i,'id'])
        j = j-1
  except:
    break
  
  j = j+1

# %%
len(l)
# Out:
# 119

# %%
print(str(len(df1)-len(df)))
# Out:
# 119

# %%
l
# Out:
# [14063705,
#  14165052,
#  14328652,
#  14354904,
#  14373503,
#  14384418,
#  14434764,
#  14515760,
#  14515769,
#  14515781,
#  14515790,
#  14515880,
#  14519928,
#  14520006,
#  14520049,
#  14520055,
#  14520067,
#  14520117,
#  14520150,
#  14520159,
#  14520166,
#  14520175,
#  14520202,
#  14520203,
#  14520205,
#  14520232,
#  14520247,
#  14520268,
#  14520275,
#  14520278,
#  14520290,
#  14520296,
#  14520297,
#  14520347,
#  14520389,
#  14520390,
#  14520394,
#  14520397,
#  14520398,
#  14520462,
#  14520495,
#  14520550,
#  14520602,
#  14520623,
#  14520760,
#  14520763,
#  14520777,
#  14520789,
#  14520807,
#  14520826,
#  14520857,
#  14520881,
#  14520885,
#  14520898,
#  14520921,
#  14520938,
#  14520986,
#  14521007,
#  14521089,
#  14521123,
#  14521196,
#  14521232,
#  14521253,
#  14521267,
#  14521280,
#  14521283,
#  14521329,
#  14521338,
#  14521339,
#  14521382,
#  14521393,
#  14521413,
#  14521417,
#  14521422,
#  14806372,
#  14824660,
# ...

# %%
for i in l:
  df1 = df1[df1['id']!=i]

# %%
print(str(len(df1)-len(df)))
# Out:
# 0

# %%
df1.head()
# Out:
#          id                                          geom  ...  ward  is_rare
# 0  14038741   POINT (73.89543905900004 18.48682755200003)  ...    61    False
# 1  14038742  POINT (73.81630115200007 18.557149113000033)  ...     8    False
# 2  14038743  POINT (73.79202280200006 18.505883990000022)  ...    29    False
# 3  14038744  POINT (73.81626896600004 18.557148160000054)  ...     8    False
# 4  14038745   POINT (73.81626192500005 18.55715006700007)  ...     8    False
#
# [5 rows x 26 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  girth_cm  height_m  ...  dist_MPCB_KR dist_MPCB_NS dist_MPCB_SWGT
# 0           0        10         2  ...      6.554280     7.509323       4.888684
# 1           1       115        10  ...      5.539697     5.708145       7.095322
# 2           2        15         2  ...      5.076020     3.753423       6.400050
# 3           3        13         2  ...      5.541110     5.708749       7.097067
# 4           4        25         7  ...      5.541631     5.709113       7.097648
#
# [5 rows x 11 columns]

# %%
df = df.drop(columns = ['Unnamed: 0'])

# %%
df = df[['dist_MPCB_KR','dist_MPCB_NS','dist_MPCB_SWGT']]
df.head()
# Out:
#    dist_MPCB_KR  dist_MPCB_NS  dist_MPCB_SWGT
# 0      6.554280      7.509323        4.888684
# 1      5.539697      5.708145        7.095322
# 2      5.076020      3.753423        6.400050
# 3      5.541110      5.708749        7.097067
# 4      5.541631      5.709113        7.097648

# %%
df7 =pd.concat([df1, df.reindex(df1.index)], axis=1)

# %%
df7
# Out:
#                id  ... dist_MPCB_SWGT
# 0        14038741  ...       4.888684
# 1        14038742  ...       7.095322
# 2        14038743  ...       6.400050
# 3        14038744  ...       7.097067
# 4        14038745  ...       7.097648
# ...           ...  ...            ...
# 4009618  18048359  ...            NaN
# 4009619  18048360  ...            NaN
# 4009620  18048361  ...            NaN
# 4009621  18048362  ...            NaN
# 4009622  18048363  ...            NaN
#
# [4009504 rows x 29 columns]

# %%
df7.to_csv('final_trees.csv')

# %%
# !mv final_trees.csv '/content/gdrive/My Drive/Tree/'
