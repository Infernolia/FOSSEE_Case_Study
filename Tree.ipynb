# %%
import pandas as pd
import numpy as np

# %%
df  = pd.read_csv("TREE.csv")

# %%
df
# Out:
#        Region  Tree_Count  Median_Girth  Median_Girth_Low  Median_Girth_High  \
# 0  Karve Road       30618          0.60             15255              15363
# 1    Nal Stop       25913          0.59             12814              13099
# 2    Swargate       21536          0.62             10693              10843
#
#    Median_Canopy  Median_Canopy_Low  Median_Canopy_High  Median_Height  \
# 0              4              14517               16101              7
# 1              4              11987               13926              7
# 2              4               9673               11863              8
#
#    Median_Height_Low  ...              Tree_6       Tree_7            Tree_8  \
# 0              14143  ...  Cluster Fig Tree\t  Sonchapha\t              Neem
# 1              12354  ...                Neem    Sonchapha  Cluster Fig Tree
# 2               9762  ...           Subabul\t         Neem             Pipal
#
# ...

# %%
for i in df.columns[1:17]:
    
    x = df[i].corr(df['SO2'])
    y = df[i].corr(df['NOx'])
    z = df[i].corr(df['AQI'])
    a = df[i].corr(df['PM10'])
    b = df[i].corr(df['Other_Tree_Count'])
    print ("\n\n" + str(i) + "\n SO2: " + str(x) + " \n NOx: " + str(y) + "\n AQI: " + str(z) + "\n  PM10: " + str(a) + "\n Other Tree Count: " + str(b))
# Out:
# Tree_Count
#  SO2: -0.7984390890220584
#  NOx: -0.9548232181503891
#  AQI: -0.7453666673628687
#   PM10: 0.002241693750726003
#  Other Tree Count: -0.9016489916252264
#
#
# Median_Girth
#  SO2: 0.04676097647914122
#  NOx: 0.38124642583151164
#  AQI: -0.036827146210517726
#   PM10: -0.7708419944740396
#  Other Tree Count: 0.9086773523953751
#
#
# Median_Girth_Low
#  SO2: -0.8101019062248965
#  NOx: -0.9604717829300081
#  AQI: -0.7583071668764382
#   PM10: -0.01738514529941402
#  Other Tree Count: -0.8929874919642162
#
#
# Median_Girth_High
#  SO2: -0.7863459864164725
#  NOx: -0.9487440630173446
#  AQI: -0.732003710531265
#   PM10: 0.022066256809470598
#  Other Tree Count: -0.9100454986662966
#
#
# Median_Canopy
#  SO2: nan
#  NOx: nan
#  AQI: nan
#   PM10: nan
#  Other Tree Count: nan
#
#
# Median_Canopy_Low
#  SO2: -0.8013742023812942
#  NOx: -0.9562652343273661
#  AQI: -0.7486182625191578
#   PM10: -0.002649173268046004
#  Other Tree Count: -0.8995230674759808
#
#
# ...
